# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Final Project - Data Science Tools and Ecosystem - Alex

# %% [markdown]
# In this notebook, I will summarize key concepts from the course "Tools for Data Science". The notebook will cover programming languages, libraries, tools, and basic arithmetic operations used in data science.

# %% [markdown]
# ## Popular Languages for Data Science
#
# Some of the most popular languages that data scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# ## Commonly Used Libraries in Data Science
#
# Some of the commonly used libraries by data scientists include:
#
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn
# - TensorFlow

# %% [markdown]
# ## Data Science Tools
#
# | Tool           | Description                          |
# |----------------|--------------------------------------|
# | JupyterLab     | Web-based interactive development    |
# | RStudio        | IDE for R                            |
# | Apache Zeppelin| Web-based notebook for big data      |

# %% [markdown]
# ## Arithmetic Expressions Examples
#
# Below are some examples of simple arithmetic expressions in Python:
#
# - Addition: `3 + 7`
# - Multiplication: `5 * 6`
# - Combined: `(3 * 5) + 8`

# %%
# This expression multiplies 3 and 7, then adds 8
(3 * 7) + 8
# Out:
# 29

# %%
# This will convert 260 minutes to hours by dividing by 60
minutes = 260
hours = minutes / 60
hours
# Out:
# 4.333333333333333

# %%
# Objectives of this notebook
objectives = [
    "List popular languages for Data Science, Phyton and R",
    "List commonly used libraries in Data Science",
    "Use Jupyter Notebooks to write and execute code"
]
for obj in objectives:
    print(f"- {obj}")
# Out:
# - List popular languages for Data Science, Phyton and R
# - List commonly used libraries in Data Science
# - Use Jupyter Notebooks to write and execute code

# %% [markdown]
# ## Author
# Alex Yucra
